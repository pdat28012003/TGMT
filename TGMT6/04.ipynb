# %%
from PIL import Image
from imagetools import*

# %%
my_path='C:/Users/dat/Downloads/picture/04.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x271>

# %%
#dinh vi khu vuc cat
region =(100,75,175,175)
#cat vung anh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x100>

# %%
# Dán
# Xác định vị trí cần dán
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x271>
