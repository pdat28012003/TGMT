# %%
from PIL import Image
from imagetools import*

# %%
my_path='C:/Users/dat/Downloads/picture/03.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=418x580>

# %%
print(img.size)
# Out:
# (418, 580)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
thumbnail_size=(30,38)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=27x38>
