# %%
from imagetools import *

# %%
dir = 'C:/Users/dat/Downloads/picture'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs :
    print(img.size)
    display(img)
# Out:
# (236, 511)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x511>
# (236, 511)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=236x511>
